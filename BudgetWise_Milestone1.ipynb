# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load Dataset
data = pd.read_csv("expenses.csv")

# %%
print("Expense Data Preview:")
display(data.head(20))
# Out:
# Expense Data Preview:
#          Date       Category           Description  Amount
# 0  2025-09-01           Food                 Lunch     200
# 1  2025-09-01      Transport              Bus fare      50
# 2  2025-09-02       Shopping               Clothes    1200
# 3  2025-09-03  Entertainment          Movie ticket     300
# 4  2025-09-03           Food                Dinner     350
# 5  2025-09-04          Bills      Electricity Bill     900
# 6  2025-09-05      Transport              Cab fare     120
# 7  2025-09-05         Health              Medicine     250
# 8  2025-09-06       Shopping                 Shoes    1500
# 9  2025-09-07  Entertainment  Netflix Subscription     500

# %%
amounts = np.array(data['Amount'])
print(amounts)

total_expense = np.sum(amounts)
average_expense = np.mean(amounts)

print(f"Total Expense: ₹{total_expense}")
print(f"Average Expense: ₹{average_expense:.2f}")
# Out:
# [ 200   50 1200  300  350  900  120  250 1500  500]
# Total Expense: ₹5370
# Average Expense: ₹537.00

# %%
# Category-wise analysis
category_summary = data.groupby('Category')['Amount'].sum().sort_values(ascending=False)
print("\n Category-wise Total Expense:")
display(category_summary)
# Out:
#  Category-wise Total Expense:
# Category
# Shopping         2700
# Bills             900
# Entertainment     800
# Food              550
# Health            250
# Transport         170
# Name: Amount, dtype: int64

# %%
# Category-wise expense(Bar chart)
plt.figure(figsize=(9,6))
bars = plt.bar(category_summary.index, category_summary.values, color='lightgreen', edgecolor='black')
plt.title('Category-wise Expense Distribution', fontsize=14, fontweight='bold')
plt.xlabel('Expense Category', fontsize=12)
plt.ylabel('Total Amount (₹)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
# Daily expense trend (Line chart)
daily_summary = data.groupby('Date')['Amount'].sum()
print(daily_summary)

plt.figure(figsize=(9,6))
plt.plot(daily_summary.index, daily_summary.values, color='royalblue', marker='o', linewidth=2)
plt.title('Daily Spending Trend', fontsize=14, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Total Daily Expense (₹)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Date
# 2025-09-01     250
# 2025-09-02    1200
# 2025-09-03     650
# 2025-09-04     900
# 2025-09-05     370
# 2025-09-06    1500
# 2025-09-07     500
# Name: Amount, dtype: int64
